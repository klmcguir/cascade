# %% [markdown]
# # Plot mean respones for single cells across days, save into folders based on driven, not driven, inhibitory driven

# %%
from cascade import df
from cascade import tca
from cascade import paths
import flow
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cascade as cas

# %%
cas.plotting.xday.mean_response('OA27', word='dual', drive_type='inhibition', drive_threshold=15)

# %%
mouse='CC175'
trace_type='zscore_day'
word='dual'
drive_threshold=15
drive_css = ('0', '135', '270')
smooth = True
drive_type = 'trial'

# %%
# get drive across all days
days = flow.DateSorter.frommeta(mice=[mouse], tags=None)
all_driven_trial = tca._group_drive_ids(days, drive_css, drive_threshold, drive_type='trial')
all_driven_vis = tca._group_drive_ids(days, drive_css, drive_threshold, drive_type='visual')
all_driven_inhib = tca._group_drive_ids(days, drive_css, drive_threshold, drive_type='inhib')
drivers = {'trial': all_driven_trial, 'visual': all_driven_vis, 'inhibition': all_driven_inhib}

# %%
# load metadata
load_dir = os.path.join(flow.paths.outd, str(mouse))
meta_path = os.path.join(load_dir, str(mouse) + '_df_trialmeta.pkl')
dfm = pd.read_pickle(meta_path)
xmap = df.get_xdaymap(mouse)

# %%
for cell_idx in drivers[drive_type]:
    dft = df.singlecell(mouse, trace_type, cell_idx, xmap=xmap, word=word)
    dft = dft.reset_index(level=['cell_idx', 'timestamp'])

    # filter metadata trials before merging
    trial_indexer = (
        ((dfm.orientation == 0) | (dfm.orientation == 135)
         | (dfm.orientation == 270)) &
        ((dfm.tag == 'standard') | (dfm.tag == 'learning_start')
         | (dfm.tag == 'reversal1_start') | (dfm.tag == 'reversal2_start')) &
        ((dfm.condition == 'plus') | (dfm.condition == 'minus')
         | (dfm.condition == 'neutral')) &
        (dfm.hunger == 'hungry'))
    dfm = dfm.loc[trial_indexer, :]

    # merge on filtered trials
    dff = pd.merge(dft, dfm, on=['mouse', 'date', 'run', 'trial_idx'],
                   how='inner')

    # smooth signal with rolling 3 unit window
    if smooth:
        dff['trace'] = dff['trace'].rolling(3).mean()

    # get timestamp info for plotting lines
    times = np.unique(dff['timestamp'])
    zero_sec = np.where(times <= 0)[0][-1]
    three_sec = np.where(times <= 3)[0][-1]
    
    # oris
    oris = np.array([0, 135, 270])
        
    # get pivot table for slicing
    toplot = dff.pivot_table(
        index=['date', 'run', 'trial_idx', 'orientation', 'learning_state'],
        columns='timestamp', values='trace')
    
    # create mean response per day per orientation for each cell
    mean_list = []
    for d in np.unique(toplot.reset_index()['date']):
        for o in oris:
            indexer = np.where((toplot.reset_index()['orientation'] == o) &
                       (toplot.reset_index()['date'] == d))[0]
#             test = toplot.iloc[indexer, :].mean(level=['date', 'orientation','learning_state'])
#             mean_list[str(o)].append(toplot.iloc[indexer, :].mean(level))
        
            mean_list.append(toplot.iloc[indexer, :].mean(level=['date', 'orientation', 'learning_state']))
        
    
    mean_df = pd.concat(mean_list, axis=0)
    
    # subplot params
    rows = 1
    cols = 3

    # get plot with most lines for figure legend
    count = []
    for col in range(cols):
        count.append(np.nansum(mean_df.reset_index()['orientation'] == oris[col]))
    legend_ind = np.argmax(count)
    color_ind = np.array([np.where(np.unique(mean_df.reset_index()['date']) == i)[0][0] for i in mean_df.reset_index()['date']])
    # colormap 
    day_num = len(np.unique(mean_df.reset_index()['date']))
    a = sns.color_palette("Greys", int(np.ceil(day_num*1.5)))[-day_num:]
    b = sns.color_palette("Greens", day_num)
    c = sns.color_palette("Reds", day_num)
    d = sns.color_palette("Purples", day_num)
    colors = {'naive': a, 'learning': b, 'reversal1': c, 'reversal2': d}

    # preallocate for legend
    labels = []

    # get driven tag for title
    ttag = 'trial, ' if np.isin(cell_idx, all_driven_trial) else ''
    vtag = 'visually, ' if np.isin(cell_idx, all_driven_vis) else ''
    itag = 'inhibition' if np.isin(cell_idx, all_driven_inhib) else ''
    title_tage = ttag + vtag + itag

    fig, axes = plt.subplots(rows, cols, figsize=(16, 4))
    fig.suptitle('Cell #' + str(cell_idx) + ' - driven: ' + title_tage, fontsize=16, y=1.05, weight='bold')
    for col in range(cols):
        indexer = np.where(mean_df.reset_index()['orientation'] == oris[col])[0]
        traces = mean_df.iloc[indexer,:].values
        dates = mean_df.reset_index()['date'].iloc[indexer]
        state = mean_df.reset_index()['learning_state'].iloc[indexer]
        c_ind = color_ind[indexer]
        axes[col].set_title('Orientation = ' + str(oris[col]))
        if col == 0:
            axes[col].set_ylabel(r'$\Delta$' + 'F/F (z-score)')
        axes[col].set_xlabel('Time from stimulus onset (sec)')
        for l in range(np.shape(traces)[0]):
            axes[col].plot(times, traces[l,:], color=colors[state.iloc[l]][c_ind[l]], label=(str(dates.iloc[l]) + '-' + state.iloc[l]))
            if col == legend_ind:
                labels.append(str(dates.iloc[l]) + '-' + state.iloc[l])
    lgd = axes[-1].legend(axes[legend_ind].lines, labels, loc='upper left', bbox_to_anchor=(1.02, 1.03), title='Days')

    # match y-limits
    ys = []
    for col in range(cols):
        ys.extend(axes[col].get_ylim())
    maxy = np.max(ys)
    miny = np.min(ys)
    for col in range(cols):
        axes[col].set_ylim((miny, maxy))
    
    # save 
    save_dir = paths.df_plots(mouse, pars={'trace_type': trace_type}, word=word, plot_type='traces')
    save_dir = os.path.join(save_dir, 'driven ' + str('trial'))
    if not os.path.isdir(save_dir): os.mkdir(save_dir)
    path = os.path.join(save_dir, str(mouse) + '_cell_' + str(cell_idx) + '_' + trace_type + '_' + drive_type + '.pdf')
    plt.savefig(path, bbox_inches='tight')
    print('Cell: ' + str(cell_idx) + ': done.')
#     plt.close()
    break
# Out:
# Cell: 1: done.

# %%
mean_df
np.where(np.diff([0, 0, 0]))[0]
# Out:
# array([], dtype=int64)

# %%
axes[0].lines
# Out:
# [<matplotlib.lines.Line2D at 0x1ca8709fd0>,
#  <matplotlib.lines.Line2D at 0x1ca8712828>,
#  <matplotlib.lines.Line2D at 0x1ca8709ba8>,
#  <matplotlib.lines.Line2D at 0x1ca8712550>,
#  <matplotlib.lines.Line2D at 0x1ca8712f60>,
#  <matplotlib.lines.Line2D at 0x1ca87182e8>,
#  <matplotlib.lines.Line2D at 0x1ca8718630>,
#  <matplotlib.lines.Line2D at 0x1ca8718978>]

# %%
mean_df
# Out:
# timestamp                          -1.000000  -0.935442  -0.870884  -0.806327  \
# date   orientation learning_state
# 170116 0           naive            0.248849   0.233258   0.185421   0.131173
#        135         naive            0.397062   0.282469   0.171140   0.173003
#        270         naive            0.146883   0.089104   0.029664   0.051917
# 170118 0           naive            0.367361   0.226976   0.058269   0.034301
#        135         naive            0.059646   0.047730   0.022160   0.004994
#        270         naive            0.050918   0.037290   0.026611   0.020503
# 170119 0           naive            0.152734   0.118924   0.056255   0.031092
#        135         naive            0.042135   0.042794   0.016967   0.003409
#        270         naive            0.075085   0.082176   0.065104  -0.000707
# 170125 0           naive            0.018225   0.012827   0.004543  -0.011657
#        135         naive           -0.050152  -0.034998  -0.018168  -0.006961
#        270         naive           -0.038991  -0.087380  -0.117420  -0.110451
#                    learning        -0.004111   0.005560   0.071124   0.049288
# 170127 270         learning        -0.159217  -0.128773  -0.079072  -0.048201
# 170201 270         learning         0.007152   0.000311  -0.009967  -0.019639
# 170326 0           reversal1       -0.050718  -0.032438  -0.000025   0.004038
#        135         reversal1        0.025939   0.043031   0.049134   0.045467
#        270         reversal1       -0.016950  -0.029820  -0.040274  -0.022556
# 170404 0           reversal1        0.017004   0.016247   0.010733  -0.015799
#        135         reversal1        0.055509   0.033674   0.014576   0.006012
#        270         reversal1       -0.009192  -0.024004  -0.015207   0.005340
#
# timestamp                          -0.741769  -0.677211  -0.612653  -0.548096  \
# date   orientation learning_state
# 170116 0           naive            0.100313   0.096169   0.091684   0.073595
#        135         naive            0.158225   0.142691   0.121890   0.089065
#        270         naive            0.038608   0.003329  -0.038310  -0.058262
# 170118 0           naive            0.014234  -0.008457  -0.015846  -0.021532
#        135         naive            0.025367   0.033265   0.016512  -0.013051
#        270         naive            0.021879   0.028119   0.036336   0.023179
# 170119 0           naive            0.018041   0.029613   0.027044   0.017219
#        135         naive           -0.011647  -0.004793   0.012913   0.033470
#        270         naive           -0.029967  -0.056814  -0.083016  -0.086157
# 170125 0           naive           -0.013056  -0.008648   0.007487   0.014231
#        135         naive            0.002446  -0.002644   0.008029   0.041833
#        270         naive           -0.092703  -0.079458  -0.082679  -0.048752
#                    learning         0.054838   0.073424   0.069905   0.024974
# 170127 270         learning        -0.035573  -0.010023  -0.008816   0.060706
# 170201 270         learning        -0.027734  -0.011661   0.013724   0.038256
# 170326 0           reversal1        0.010638   0.027941   0.039701   0.020786
#        135         reversal1        0.020051  -0.019574  -0.033366  -0.030513
#        270         reversal1       -0.001032   0.013633  -0.003298  -0.019776
# 170404 0           reversal1       -0.014642  -0.000779   0.016268   0.016070
#        135         reversal1       -0.007450  -0.009170  -0.000972   0.009974
#        270         reversal1        0.008713  -0.010761  -0.027150  -0.029422
#
# timestamp                          -0.483538  -0.418980  ...   5.326662  \
# date   orientation learning_state                        ...
# 170116 0           naive            0.036810  -0.005917  ...   0.557294
#        135         naive            0.037517  -0.019304  ...   0.205753
#        270         naive           -0.049960  -0.009853  ...   0.350017
# 170118 0           naive           -0.028199  -0.032509  ...   0.052533
#        135         naive           -0.025804  -0.017870  ...   0.632347
#        270         naive           -0.008099  -0.043330  ...   0.139945
# 170119 0           naive            0.004910   0.009093  ...  -0.041996
#        135         naive            0.036569   0.005738  ...   0.613657
#        270         naive           -0.017202   0.066305  ...  -0.080383
# 170125 0           naive            0.020060   0.022088  ...  -0.031355
#        135         naive            0.078910   0.085843  ...  -0.046626
#        270         naive            0.037516   0.125582  ...  -0.034787
#                    learning        -0.041563  -0.104937  ...  -0.028635
# 170127 270         learning         0.118509   0.156317  ...  -0.256043
# 170201 270         learning         0.040879   0.028391  ...  -0.039094
# 170326 0           reversal1       -0.001318  -0.024018  ...  -0.083324
#        135         reversal1       -0.012458   0.005818  ...  -0.010452
#        270         reversal1       -0.017692   0.005397  ...   0.035814
# 170404 0           reversal1        0.013364   0.005754  ...   0.176867
#        135         reversal1        0.010970   0.016813  ...  -0.056295
#        270         reversal1       -0.013447   0.002732  ...   0.077050
#
# timestamp                           5.391220   5.455778   5.520336   5.584894  \
# date   orientation learning_state
# 170116 0           naive            0.525366   0.476128   0.420010   0.378081
#        135         naive            0.234349   0.269156   0.321926   0.395930
#        270         naive            0.379321   0.369711   0.328793   0.283517
# 170118 0           naive            0.010694  -0.017876  -0.012401   0.027487
#        135         naive            0.693649   0.704430   0.663738   0.590438
#        270         naive            0.120932   0.081923   0.042295   0.011954
# 170119 0           naive           -0.048730  -0.044908  -0.033007  -0.030809
#        135         naive            0.539201   0.479066   0.443739   0.420124
#        270         naive           -0.115697  -0.134508  -0.132549  -0.103088
# 170125 0           naive           -0.051897  -0.100491  -0.121074  -0.106501
#        135         naive           -0.057377  -0.047698  -0.052196  -0.033767
#        270         naive           -0.072723  -0.124926  -0.146716  -0.153355
#                    learning        -0.033909  -0.007059   0.074199   0.085138
# 170127 270         learning        -0.288363  -0.297952  -0.306025  -0.304284
# 170201 270         learning        -0.026684  -0.019668  -0.020306  -0.024249
# 170326 0           reversal1       -0.121497  -0.120663  -0.084562  -0.038488
#        135         reversal1       -0.037998  -0.042809  -0.045646  -0.038128
#        270         reversal1        0.036331   0.075003   0.094641   0.085285
# 170404 0           reversal1        0.165599   0.122828   0.090940   0.064694
#        135         reversal1       -0.063907  -0.053333  -0.045105  -0.038589
#        270         reversal1        0.106617   0.103910   0.078992   0.053768
#
# timestamp                           5.649451   5.714009   5.778567   5.843125  \
# date   orientation learning_state
# 170116 0           naive            0.373370   0.401277   0.427475   0.430610
#        135         naive            0.483570   0.536583   0.541058   0.512573
#        270         naive            0.258793   0.242119   0.214900   0.166692
# 170118 0           naive            0.081893   0.111049   0.120091   0.115230
#        135         naive            0.539102   0.506974   0.478684   0.440942
#        270         naive            0.004598   0.008372   0.020898   0.044190
# 170119 0           naive           -0.027254  -0.019779  -0.003503   0.024291
#        135         naive            0.385230   0.344728   0.308525   0.284329
#        270         naive           -0.087824  -0.104301  -0.137194  -0.146127
# 170125 0           naive           -0.063063  -0.039188  -0.029416  -0.050116
#        135         naive           -0.017115   0.010551   0.034069   0.054034
#        270         naive           -0.146691  -0.129982  -0.092410  -0.059349
#                    learning         0.035248  -0.006065   0.034876   0.089401
# 170127 270         learning        -0.320419  -0.269792  -0.227925  -0.186457
# 170201 270         learning        -0.021901  -0.007644   0.003167   0.016050
# 170326 0           reversal1       -0.022614  -0.049019  -0.076996  -0.096229
#        135         reversal1       -0.034125  -0.026421  -0.025570  -0.033193
#        270         reversal1        0.063009   0.063460   0.073038   0.078848
# 170404 0           reversal1        0.056857   0.043130   0.065496   0.109578
#        135         reversal1       -0.049429  -0.053794  -0.059140  -0.052794
#        270         reversal1        0.044981   0.029548   0.012795  -0.004586
#
# timestamp                           5.907682
# date   orientation learning_state
# 170116 0           naive            0.426500
#        135         naive            0.483322
#        270         naive            0.124509
# 170118 0           naive            0.109369
#        135         naive            0.423699
#        270         naive            0.087832
# 170119 0           naive            0.059673
#        135         naive            0.281436
#        270         naive           -0.137160
# 170125 0           naive           -0.063655
#        135         naive            0.069628
#        270         naive           -0.068660
#                    learning         0.051613
# 170127 270         learning        -0.192720
# 170201 270         learning         0.012480
# 170326 0           reversal1       -0.093159
#        135         reversal1       -0.036338
#        270         reversal1        0.068966
# 170404 0           reversal1        0.153394
#        135         reversal1       -0.059121
#        270         reversal1       -0.016548
#
# [21 rows x 108 columns]

# %%
# subplot params
rows = 1
cols = 3

# get plot with most lines for figure legend
count = []
for col in range(cols):
    count.append(np.nansum(mean_df.reset_index()['orientation'] == oris[col]))
legend_ind = np.argmax(count)
color_ind = np.array([np.where(np.unique(mean_df.reset_index()['date']) == i)[0][0] for i in mean_df.reset_index()['date']])
# colormap 
day_num = len(np.unique(mean_df.reset_index()['date']))
a = sns.color_palette("Greys", int(np.floor(day_num*1.5)))[-day_num:-1]
b = sns.color_palette("Greens", day_num)
c = sns.color_palette("Reds", day_num)
d = sns.color_palette("Purples", day_num)
colors = {'naive': a, 'learning': b, 'reversal1': c, 'reversal2': d}

# preallocate for legend
labels = []

# get driven tag for title
ttag = 'trial, ' if np.isin(cell_idx, all_driven_trial) else ''
vtag = 'visually, ' if np.isin(cell_idx, all_driven_vis) else ''
itag = 'inhibition' if np.isin(cell_idx, all_driven_inhib) else ''
title_tage = ttag + vtag + itag

fig, axes = plt.subplots(rows, cols, figsize=(16, 4))
fig.suptitle('Cell #' + str(cell_idx) + ' - driven: ' + title_tage, fontsize=16, y=1.05, weight='bold')
for col in range(cols):
    indexer = np.where(mean_df.reset_index()['orientation'] == oris[col])[0]
    traces = mean_df.iloc[indexer,:].values
    dates = mean_df.reset_index()['date'].iloc[indexer]
    state = mean_df.reset_index()['learning_state'].iloc[indexer]
    c_ind = color_ind[indexer]
    axes[col].set_title('Orientation = ' + str(oris[col]))
    if col == 0:
        axes[col].set_ylabel(r'$\Delta$' + 'F/F (z-score)')
    axes[col].set_xlabel('Time from stimulus onset (sec)')
    for l in range(np.shape(traces)[0]):
        ln = axes[col].plot(times, traces[l,:], color=colors[state.iloc[l]][c_ind[l]], label=(str(dates.iloc[l]) + '-' + state.iloc[l]))
        if col == legend_ind:
            labels.append(str(dates.iloc[l]) + '-' + state.iloc[l])
    if col == legend_ind:
        axes
lgd = axes[-1].legend(axes[-1].lines, labels, loc='upper left', bbox_to_anchor=(1.02, 1.03), title='Days')

# match y-limits
ys = []
for col in range(cols):
    ys.extend(axes[col].get_ylim())
maxy = np.max(ys)
miny = np.min(ys)
for col in range(cols):
    axes[col].set_ylim((miny, maxy))

drive_type = 'trial'
save_dir = paths.df_plots(mouse, pars={'trace_type': trace_type}, word=word, plot_type='traces')
save_dir = os.path.join(save_dir, 'driven ' + str('trial'))
if not os.path.isdir(save_dir): os.mkdir(save_dir)
path = os.path.join(save_dir, str(mouse) + '_cell_' + str(cell_idx) + '_' + trace_type + '_' + drive_type + '.pdf')
print('Cell: ' + str(cell_idx) + ': done.')
plt.savefig(path, bbox_inches='tight')
plt.close()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-269-b622d1b097b6> in <module>
# ----> 1 axes[0].label
#
# AttributeError: 'AxesSubplot' object has no attribute 'label'

# %%
g = sns.FacetGrid(
    dff.reset_index(), col='orientation', hue='date',
    height=8, aspect=1, sharey=False, dropna=True, palette=cmap, legend_out=True)
cmap = sns.cubehelix_palette(len(np.unique(dff.reset_index()['date'])), start=.5, rot=-.75)
g.map(sns.lineplot, 'timestamp', 'trace', err_style=None)
# test = dff.reset_index().set_index(['date', 'orientation', 'learning_state', 'timestamp']).mean(level=['date', 'orientation', 'learning_state', 'timestamp'])

# %%
test.head()
# Out:
#                                              run  trial_idx  cell_idx  \
# date   orientation learning_state timestamp
# 170116 0           naive          -1.000000  3.0  76.804348       1.0
#                                   -0.935442  3.0  76.804348       1.0
#                                   -0.870884  3.0  76.804348       1.0
#                                   -0.806327  3.0  76.804348       1.0
#                                   -0.741769  3.0  76.804348       1.0
#
#                                                 trace  trialerror  firstlick  \
# date   orientation learning_state timestamp
# 170116 0           naive          -1.000000  0.248849         1.0        NaN
#                                   -0.935442  0.233258         1.0        NaN
#                                   -0.870884  0.185421         1.0        NaN
#                                   -0.806327  0.131173         1.0        NaN
#                                   -0.741769  0.100313         1.0        NaN
#
#                                              ensure  quinine  speed
# date   orientation learning_state timestamp
# 170116 0           naive          -1.000000     NaN      NaN    NaN
#                                   -0.935442     NaN      NaN    NaN
#                                   -0.870884     NaN      NaN    NaN
#                                   -0.806327     NaN      NaN    NaN
#                                   -0.741769     NaN      NaN    NaN

# %%
sns.set()
sns.set_context("notebook")
sns.lineplot(x='timestamp', y='trace', data=test.reset_index(), hue='date', err_style=None)

# %%
sns.lineplot(x='timestamp', y='trace', data=dff.reset_index('date'), hue='learning_state', err_style=None)

# %%
plt.plot(pd.concat(mean_list['0'], axis=1))
# Out:
# [<matplotlib.lines.Line2D at 0x1c1b72b828>,
#  <matplotlib.lines.Line2D at 0x1c1c650710>,
#  <matplotlib.lines.Line2D at 0x1c1c4ea0f0>,
#  <matplotlib.lines.Line2D at 0x1c1c4ea240>,
#  <matplotlib.lines.Line2D at 0x1c1c4ea390>,
#  <matplotlib.lines.Line2D at 0x1c1c4ea4e0>,
#  <matplotlib.lines.Line2D at 0x1c1c4ea630>,
#  <matplotlib.lines.Line2D at 0x1c1c4ea780>]

# %%
dff.reset_index().groupby(['mouse', 'date', 'orientation']).head()
# Out:
#        mouse    date  run  trial_idx  cell_idx  timestamp     trace  \
# 0       OA27  170116    3        0.0       1.0  -1.000000       NaN
# 1       OA27  170116    3        0.0       1.0  -0.935442       NaN
# 2       OA27  170116    3        0.0       1.0  -0.870884 -0.022615
# 3       OA27  170116    3        0.0       1.0  -0.806327  0.041145
# 4       OA27  170116    3        0.0       1.0  -0.741769  0.052752
# 108     OA27  170116    3        1.0       1.0  -1.000000 -1.288645
# 109     OA27  170116    3        1.0       1.0  -0.935442 -0.715852
# 110     OA27  170116    3        1.0       1.0  -0.870884 -0.131758
# 111     OA27  170116    3        1.0       1.0  -0.806327 -0.115172
# 112     OA27  170116    3        1.0       1.0  -0.741769 -0.064755
# 216     OA27  170116    3        2.0       1.0  -1.000000  0.393407
# 217     OA27  170116    3        2.0       1.0  -0.935442  0.219924
# 218     OA27  170116    3        2.0       1.0  -0.870884  0.068997
# 219     OA27  170116    3        2.0       1.0  -0.806327  0.083047
# 220     OA27  170116    3        2.0       1.0  -0.741769  0.124623
# 15012   OA27  170118    3        0.0       1.0  -1.000000       NaN
# 15013   OA27  170118    3        0.0       1.0  -0.935442       NaN
# 15014   OA27  170118    3        0.0       1.0  -0.870884  0.022597
# 15015   OA27  170118    3        0.0       1.0  -0.806327  0.089586
# 15016   OA27  170118    3        0.0       1.0  -0.741769  0.179527
# 15120   OA27  170118    3        1.0       1.0  -1.000000 -0.978204
# 15121   OA27  170118    3        1.0       1.0  -0.935442 -1.512529
# 15122   OA27  170118    3        1.0       1.0  -0.870884 -2.003102
# 15123   OA27  170118    3        1.0       1.0  -0.806327 -1.670138
# 15124   OA27  170118    3        1.0       1.0  -0.741769 -1.213372
# 15228   OA27  170118    3        2.0       1.0  -1.000000 -0.870352
# 15229   OA27  170118    3        2.0       1.0  -0.935442 -0.314713
# 15230   OA27  170118    3        2.0       1.0  -0.870884  0.270992
# 15231   OA27  170118    3        2.0       1.0  -0.806327  0.233333
# 15232   OA27  170118    3        2.0       1.0  -0.741769  0.194013
# ...      ...     ...  ...        ...       ...        ...       ...
# 94392   OA27  170326    3        5.0       1.0  -1.000000  0.234277
# 94393   OA27  170326    3        5.0       1.0  -0.935442 -0.117811
# 94394   OA27  170326    3        5.0       1.0  -0.870884 -0.460143
# 94395   OA27  170326    3        5.0       1.0  -0.806327 -0.162127
# 94396   OA27  170326    3        5.0       1.0  -0.741769  0.101687
# 94500   OA27  170326    3        6.0       1.0  -1.000000 -0.408615
# 94501   OA27  170326    3        6.0       1.0  -0.935442 -0.334334
# 94502   OA27  170326    3        6.0       1.0  -0.870884 -0.109188
# 94503   OA27  170326    3        6.0       1.0  -0.806327  0.044810
# 94504   OA27  170326    3        6.0       1.0  -0.741769 -0.030819
# 94608   OA27  170326    3        7.0       1.0  -1.000000 -0.030907
# 94609   OA27  170326    3        7.0       1.0  -0.935442  0.269658
# 94610   OA27  170326    3        7.0       1.0  -0.870884  0.245278
# 94611   OA27  170326    3        7.0       1.0  -0.806327  0.117947
# 94612   OA27  170326    3        7.0       1.0  -0.741769  0.014495
# 135540  OA27  170404    2        0.0       1.0  -1.000000 -0.570990
# 135541  OA27  170404    2        0.0       1.0  -0.935442 -0.323853
# 135542  OA27  170404    2        0.0       1.0  -0.870884  0.028149
# 135543  OA27  170404    2        0.0       1.0  -0.806327 -0.030788
# 135544  OA27  170404    2        0.0       1.0  -0.741769 -0.049865
# 135648  OA27  170404    2        1.0       1.0  -1.000000 -0.112540
# 135649  OA27  170404    2        1.0       1.0  -0.935442  0.009494
# 135650  OA27  170404    2        1.0       1.0  -0.870884  0.138553
# 135651  OA27  170404    2        1.0       1.0  -0.806327 -0.105308
# 135652  OA27  170404    2        1.0       1.0  -0.741769 -0.180281
# 136080  OA27  170404    2        5.0       1.0  -1.000000  0.574004
# 136081  OA27  170404    2        5.0       1.0  -0.935442  0.508799
# 136082  OA27  170404    2        5.0       1.0  -0.870884  0.231176
# 136083  OA27  170404    2        5.0       1.0  -0.806327 -0.107264
# 136084  OA27  170404    2        5.0       1.0  -0.741769 -0.419367
#
#         orientation condition  trialerror  hunger learning_state       tag  \
# 0                 0      plus           1  hungry          naive  standard
# 1                 0      plus           1  hungry          naive  standard
# 2                 0      plus           1  hungry          naive  standard
# 3                 0      plus           1  hungry          naive  standard
# 4                 0      plus           1  hungry          naive  standard
# 108             135   neutral           2  hungry          naive  standard
# 109             135   neutral           2  hungry          naive  standard
# 110             135   neutral           2  hungry          naive  standard
# 111             135   neutral           2  hungry          naive  standard
# 112             135   neutral           2  hungry          naive  standard
# 216             270     minus           4  hungry          naive  standard
# 217             270     minus           4  hungry          naive  standard
# 218             270     minus           4  hungry          naive  standard
# 219             270     minus           4  hungry          naive  standard
# 220             270     minus           4  hungry          naive  standard
# 15012           135   neutral           2  hungry          naive  standard
# 15013           135   neutral           2  hungry          naive  standard
# 15014           135   neutral           2  hungry          naive  standard
# 15015           135   neutral           2  hungry          naive  standard
# 15016           135   neutral           2  hungry          naive  standard
# 15120           270     minus           4  hungry          naive  standard
# 15121           270     minus           4  hungry          naive  standard
# 15122           270     minus           4  hungry          naive  standard
# 15123           270     minus           4  hungry          naive  standard
# 15124           270     minus           4  hungry          naive  standard
# 15228             0      plus           1  hungry          naive  standard
# 15229             0      plus           1  hungry          naive  standard
# 15230             0      plus           1  hungry          naive  standard
# 15231             0      plus           1  hungry          naive  standard
# 15232             0      plus           1  hungry          naive  standard
# ...             ...       ...         ...     ...            ...       ...
# 94392           135      plus           0  hungry      reversal1  standard
# 94393           135      plus           0  hungry      reversal1  standard
# 94394           135      plus           0  hungry      reversal1  standard
# 94395           135      plus           0  hungry      reversal1  standard
# 94396           135      plus           0  hungry      reversal1  standard
# 94500           270   neutral           2  hungry      reversal1  standard
# 94501           270   neutral           2  hungry      reversal1  standard
# 94502           270   neutral           2  hungry      reversal1  standard
# 94503           270   neutral           2  hungry      reversal1  standard
# 94504           270   neutral           2  hungry      reversal1  standard
# 94608             0     minus           5  hungry      reversal1  standard
# 94609             0     minus           5  hungry      reversal1  standard
# 94610             0     minus           5  hungry      reversal1  standard
# 94611             0     minus           5  hungry      reversal1  standard
# 94612             0     minus           5  hungry      reversal1  standard
# 135540          135      plus           0  hungry      reversal1  standard
# 135541          135      plus           0  hungry      reversal1  standard
# 135542          135      plus           0  hungry      reversal1  standard
# 135543          135      plus           0  hungry      reversal1  standard
# 135544          135      plus           0  hungry      reversal1  standard
# 135648            0     minus           4  hungry      reversal1  standard
# 135649            0     minus           4  hungry      reversal1  standard
# 135650            0     minus           4  hungry      reversal1  standard
# 135651            0     minus           4  hungry      reversal1  standard
# 135652            0     minus           4  hungry      reversal1  standard
# 136080          270   neutral           2  hungry      reversal1  standard
# 136081          270   neutral           2  hungry      reversal1  standard
# 136082          270   neutral           2  hungry      reversal1  standard
# 136083          270   neutral           2  hungry      reversal1  standard
# 136084          270   neutral           2  hungry      reversal1  standard
#
#         firstlick  ensure  quinine      speed
# 0             NaN     NaN      NaN        NaN
# 1             NaN     NaN      NaN        NaN
# 2             NaN     NaN      NaN        NaN
# 3             NaN     NaN      NaN        NaN
# 4             NaN     NaN      NaN        NaN
# 108           NaN     NaN      NaN        NaN
# 109           NaN     NaN      NaN        NaN
# 110           NaN     NaN      NaN        NaN
# 111           NaN     NaN      NaN        NaN
# 112           NaN     NaN      NaN        NaN
# 216           NaN     NaN      NaN        NaN
# 217           NaN     NaN      NaN        NaN
# 218           NaN     NaN      NaN        NaN
# 219           NaN     NaN      NaN        NaN
# 220           NaN     NaN      NaN        NaN
# 15012         NaN     NaN      NaN        NaN
# 15013         NaN     NaN      NaN        NaN
# 15014         NaN     NaN      NaN        NaN
# 15015         NaN     NaN      NaN        NaN
# 15016         NaN     NaN      NaN        NaN
# 15120         NaN     NaN      NaN        NaN
# 15121         NaN     NaN      NaN        NaN
# 15122         NaN     NaN      NaN        NaN
# 15123         NaN     NaN      NaN        NaN
# 15124         NaN     NaN      NaN        NaN
# 15228         NaN     NaN      NaN        NaN
# 15229         NaN     NaN      NaN        NaN
# 15230         NaN     NaN      NaN        NaN
# 15231         NaN     NaN      NaN        NaN
# 15232         NaN     NaN      NaN        NaN
# ...           ...     ...      ...        ...
# 94392        24.5    67.5      NaN   8.443276
# 94393        24.5    67.5      NaN   8.443276
# 94394        24.5    67.5      NaN   8.443276
# 94395        24.5    67.5      NaN   8.443276
# 94396        24.5    67.5      NaN   8.443276
# 94500         NaN     NaN      NaN  13.086281
# 94501         NaN     NaN      NaN  13.086281
# 94502         NaN     NaN      NaN  13.086281
# 94503         NaN     NaN      NaN  13.086281
# 94504         NaN     NaN      NaN  13.086281
# 94608        17.0     NaN      NaN  -0.074390
# 94609        17.0     NaN      NaN  -0.074390
# 94610        17.0     NaN      NaN  -0.074390
# 94611        17.0     NaN      NaN  -0.074390
# 94612        17.0     NaN      NaN  -0.074390
# 135540       24.0    67.5      NaN   7.539464
# 135541       24.0    67.5      NaN   7.539464
# 135542       24.0    67.5      NaN   7.539464
# 135543       24.0    67.5      NaN   7.539464
# 135544       24.0    67.5      NaN   7.539464
# 135648       30.0     NaN      NaN  12.986385
# 135649       30.0     NaN      NaN  12.986385
# 135650       30.0     NaN      NaN  12.986385
# 135651       30.0     NaN      NaN  12.986385
# 135652       30.0     NaN      NaN  12.986385
# 136080       21.5     NaN      NaN   6.098869
# 136081       21.5     NaN      NaN   6.098869
# 136082       21.5     NaN      NaN   6.098869
# 136083       21.5     NaN      NaN   6.098869
# 136084       21.5     NaN      NaN   6.098869
#
# [100 rows x 17 columns]
