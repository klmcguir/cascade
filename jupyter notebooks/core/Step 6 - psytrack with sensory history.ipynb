# %%
# Pillow with new weights for stimulus history
# %load_ext autoreload
# %autoreload 2
import flow
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from psytrack.plot import analysisFunctions as af
import os
import pool
import cascade as cas
import pandas as pd

# %%
pars = {'weights': {
        'bias': 1,
        'ori_0': 1,
        'ori_135': 1,
        'ori_270': 1,
        'prev_0': 1,
        'prev_135': 1,
        'prev_270': 1,
        'prev_choice': 1,
        'prev_reward': 1,
        'prev_punish': 1},
       'include_pavlovian': True}
pars_orig = {'weights': {
        'bias': 1,
        'ori_0': 1,
        'ori_135': 1,
        'ori_270': 1,
        'prev_choice': 1,
        'prev_reward': 1,
        'prev_punish': 1},
       'include_pavlovian': False}
pars_simp_th = {'weights': {
        'bias': 1,
        'ori_same_0': 1,
        'ori_same_135': 1,
        'ori_same_270': 1,
        'ori_other_0': 1,
        'ori_other_135': 1,
        'ori_other_270': 1,
        'prev_choice': 1,
        'prev_reward': 1,
        'prev_punish': 1},
       'include_pavlovian': True}
th_pars = {'weights': {
        'bias': 1,
        'ori_0_0': 1,
        'ori_135_0': 1,
        'ori_270_0': 1,
        'ori_0_135': 1,
        'ori_135_135': 1,
        'ori_270_135': 1,
        'ori_0_270': 1,
        'ori_135_270': 1,
        'ori_270_270': 1,
        'prev_choice': 1,
        'prev_reward': 1,
        'prev_punish': 1},
       'include_pavlovian': True}

# %%
# flow.Mouse(mouse=mi).runs(tags='xday', exclude_tags=['bad', 'naive'], run_types='training')
m = 'OA27'
colors = {
    'bias': '#48599e',
    'ori_0': cas.lookups.color_dict[cas.lookups.lookup_ori[m][0]],
    'ori_135': cas.lookups.color_dict[cas.lookups.lookup_ori[m][135]],
    'ori_270': cas.lookups.color_dict[cas.lookups.lookup_ori[m][270]],
    'ori_0_0': cas.lookups.color_dict[cas.lookups.lookup_ori[m][0] + '1'],
    'ori_135_0': cas.lookups.color_dict[cas.lookups.lookup_ori[m][0] + '2'],
    'ori_270_0': cas.lookups.color_dict[cas.lookups.lookup_ori[m][0] + '3'],
    'ori_0_135': cas.lookups.color_dict[cas.lookups.lookup_ori[m][135] + '1'],
    'ori_135_135': cas.lookups.color_dict[cas.lookups.lookup_ori[m][135] + '2'],
    'ori_270_135': cas.lookups.color_dict[cas.lookups.lookup_ori[m][135] + '3'],
    'ori_0_270': cas.lookups.color_dict[cas.lookups.lookup_ori[m][270] + '1'],
    'ori_135_270': cas.lookups.color_dict[cas.lookups.lookup_ori[m][270] + '2'],
    'ori_270_270': cas.lookups.color_dict[cas.lookups.lookup_ori[m][270] + '3'],
    'ori_same_0': cas.lookups.color_dict[cas.lookups.lookup_ori[m][0] + '1'],
    'ori_other_0': cas.lookups.color_dict[cas.lookups.lookup_ori[m][0] + '3'],
    'ori_same_135': cas.lookups.color_dict[cas.lookups.lookup_ori[m][135] + '1'],
    'ori_other_135': cas.lookups.color_dict[cas.lookups.lookup_ori[m][135] + '3'],
    'ori_same_270': cas.lookups.color_dict[cas.lookups.lookup_ori[m][270] + '1'],
    'ori_other_270': cas.lookups.color_dict[cas.lookups.lookup_ori[m][270] + '3'],
    'prev_0':  cas.lookups.color_dict[cas.lookups.lookup_ori[m][0] + '1'],
    'prev_135':  cas.lookups.color_dict[cas.lookups.lookup_ori[m][135] + '1'],
    'prev_270':  cas.lookups.color_dict[cas.lookups.lookup_ori[m][270] + '1'],
    'prev_answer': '#ffc905',
    'prev_choice': '#68437d',
    'prev_punish': '#c98b6c',
    'prev_reward': '#ffaf25',
    'cum_reward': '#17cc56',
}
z = flow.Mouse(mouse=m).psytracker(pars=pars_simp_th, force=False, verbose=True)

fig = af.makeWeightPlot(z.fits, z.data, z.weights_dict, perf_plot=True, bias_plot=False, errorbar=z.d['results']['credible_intervals'],
          label_names=label_names, label_order=label_order, colors=colors)

z = flow.Mouse(mouse=m).psytracker(pars=pars, force=False, verbose=True)

fig = af.makeWeightPlot(z.fits, z.data, z.weights_dict, perf_plot=True, bias_plot=False, errorbar=z.d['results']['credible_intervals'],
          label_names=label_names, label_order=label_order, colors=colors)
# Out:
# Saved PsyTracker found, loading: S:\twophoton_analysis\Data\output\psytrack\OA27\cart\OA27_cart_santa.psy
# Saved PsyTracker found, loading: S:\twophoton_analysis\Data\output\psytrack\OA27\logged\OA27_logged_santa.psy

# %%
# mice=['AS57', 'AS23', 'OA38', 'AS20', 'CB173', 'AS47', 'AS41']
# mice=['OA27', 'AS23', 'AS20', 'CB173', 'AS47', 'AS41', 'AS57']
mice =['OA26', 'OA67', 'VF226', 'OA32', 'OA34', 'OA36', 'OA38',  'CC175']
for mi in mice:
    pars_simp_th = {'weights': {
        'bias': 1,
        'ori_same_0': 1,
        'ori_same_135': 1,
        'ori_same_270': 1,
        'ori_other_0': 1,
        'ori_other_135': 1,
        'ori_other_270': 1,
        'prev_choice': 1,
        'prev_reward': 1,
        'prev_punish': 1},
       'include_pavlovian': False}
    flow.Mouse(mouse=mi).psytracker(verbose=True, pars=pars_simp_th)

    pars_simp_th = {'weights': {
        'bias': 1,
        'ori_same_0': 1,
        'ori_same_135': 1,
        'ori_same_270': 1,
        'ori_other_0': 1,
        'ori_other_135': 1,
        'ori_other_270': 1,
        'prev_choice': 1,
        'prev_reward': 1,
        'prev_punish': 1},
       'include_pavlovian': True}
    flow.Mouse(mouse=mi).psytracker(verbose=True, pars=pars_simp_th)

# %%
key = 'ori_same_0'
ind = key.rfind('_')
int(key[ind+1:])
# Out:
# 0

# %%
mice = ['OA27', 'OA26', 'OA67', 'VF226', 'OA32', 'OA34', 'OA36']
sigDs = {}
sigs = {}
for m in mice:
    psy = flow.Mouse(mouse=m).psytracker(verbose=True, pars=pars)
    sigDs[m] = psy.d['results']['hyper']['sigDay']
    sigs[m] = psy.d['results']['hyper']['sigma']

# %%
mice = ['OA34', 'OA36']
for m in mice:
    psy = flow.Mouse(mouse=m).psytracker(verbose=True, pars=th_pars)

# %% [markdown]
# # make plots

# %%
label_names = {
    'bias': 'Offset',
    'ori_0': '0',
    'ori_135': '135',
    'ori_270': '270',
    'prev_0': '$0^{-1}$',
    'prev_135': '$135^{-1}$',
    'prev_270': '$270^{-1}$',
    'ori_0_0': '$0^{-1}, 0$',
    'ori_135_0': '$135^{-1}, 0$',
    'ori_270_0': '$270^{-1}, 0$',
    'ori_0_135': '$0^{-1}, 135$',
    'ori_135_135': '$135^{-1}, 135$',
    'ori_270_135': '$270^{-1}, 135$',
    'ori_0_270': '$0^{-1}, 270$',
    'ori_135_270': '$135^{-1}, 270$',
    'ori_270_270': '$270^{-1}, 270$',
    'ori_same_0': '$same^{-1}, 0$',
    'ori_other_0': '$other^{-1}, 0$',
    'ori_same_135': '$same^{-1}, 135$',
    'ori_other_135': '$other^{-1}, 135$',
    'ori_same_270': '$same^{-1}, 270$',
    'ori_other_270': '$other^{-1}, 270$',
    'prev_answer': '$Answer^{-1}$',
    'prev_choice': '$Choice^{-1}$',
    'prev_punish': '$Punish^{-1}$',
    'prev_reward': '$Reward^{-1}$',
    'cum_reward': 'Cumulative Reward',
}
label_order = {  # CHECK THIS
    'bias': 0,
    'ori_0': 7,
    'ori_135': 8,
    'ori_270': 9,
    'ori_0': 4,
    'ori_135': 5,
    'ori_270': 6,
    'prev_0': 7,
    'prev_135': 8,
    'prev_270': 9,
    'ori_0_0': 1,
    'ori_135_0': 2,
    'ori_270_0': 3,
    'ori_0_135': 4,
    'ori_135_135': 5,
    'ori_270_135': 6,
    'ori_0_270': 7,
    'ori_135_270': 8,
    'ori_270_270': 9,
    'ori_same_0': 1,
    'ori_other_0': 2,
    'ori_same_135': 4,
    'ori_other_135': 5,
    'ori_same_270': 7,
    'ori_other_270': 8,
    'prev_answer': 10,
    'prev_choice': 11,
    'prev_punish': 12,
    'prev_reward': 13,
    'cum_reward': 14,
}
colors = {
    'bias': '#1982C4',
    'ori_0': '#ff6b46',
    'ori_135': '#9346ff',
    'ori_270': '#b2ff46',
    'prev_0': '#ffc562',
    'prev_135': '#ff62d3',
    'prev_270': '#62ffbb',
    'prev_answer': '#ffc905',
    'prev_choice': '#68437d',
    'prev_punish': '#c98b6c',
    'prev_reward': '#90c971',
    'cum_reward': '#17cc56',
}

# %%
mice = ['OA27', 'OA26', 'OA67', 'VF226', 'OA32', 'OA34', 'OA36']
mice += ['CB173', 'AS47', 'AS41']
mice += ['AS23', 'OA38', 'AS20', 'AS57']

pars = {'weights': {
        'bias': 1,
        'ori_0': 1,
        'ori_135': 1,
        'ori_270': 1,
        'prev_0': 1,
        'prev_135': 1,
        'prev_270': 1,
        'prev_choice': 1,
        'prev_reward': 1,
        'prev_punish': 1},
       'include_pavlovian': False}

pars_orig = {'weights': {
        'bias': 1,
        'ori_0': 1,
        'ori_135': 1,
        'ori_270': 1,
        'prev_choice': 1,
        'prev_reward': 1,
        'prev_punish': 1},
       'include_pavlovian': False}

pars_simp_th = {'weights': {
        'bias': 1,
        'ori_same_0': 1,
        'ori_same_135': 1,
        'ori_same_270': 1,
        'ori_other_0': 1,
        'ori_other_135': 1,
        'ori_other_270': 1,
        'prev_choice': 1,
        'prev_reward': 1,
        'prev_punish': 1},
       'include_pavlovian': False}

th_pars = {'weights': {
        'bias': 1,
        'ori_0_0': 1,
        'ori_135_0': 1,
        'ori_270_0': 1,
        'ori_0_135': 1,
        'ori_135_135': 1,
        'ori_270_135': 1,
        'ori_0_270': 1,
        'ori_135_270': 1,
        'ori_270_270': 1,
        'prev_choice': 1,
        'prev_reward': 1,
        'prev_punish': 1},
       'include_pavlovian': False}

for m in mice:
    
    colors = {
    'bias': '#48599e',
    'ori_0': cas.lookups.color_dict[cas.lookups.lookup_ori[m][0]],
    'ori_135': cas.lookups.color_dict[cas.lookups.lookup_ori[m][135]],
    'ori_270': cas.lookups.color_dict[cas.lookups.lookup_ori[m][270]],
    'ori_0_0': cas.lookups.color_dict[cas.lookups.lookup_ori[m][0] + '1'],
    'ori_135_0': cas.lookups.color_dict[cas.lookups.lookup_ori[m][0] + '2'],
    'ori_270_0': cas.lookups.color_dict[cas.lookups.lookup_ori[m][0] + '3'],
    'ori_0_135': cas.lookups.color_dict[cas.lookups.lookup_ori[m][135] + '1'],
    'ori_135_135': cas.lookups.color_dict[cas.lookups.lookup_ori[m][135] + '2'],
    'ori_270_135': cas.lookups.color_dict[cas.lookups.lookup_ori[m][135] + '3'],
    'ori_0_270': cas.lookups.color_dict[cas.lookups.lookup_ori[m][270] + '1'],
    'ori_135_270': cas.lookups.color_dict[cas.lookups.lookup_ori[m][270] + '2'],
    'ori_270_270': cas.lookups.color_dict[cas.lookups.lookup_ori[m][270] + '3'],
    'ori_same_0': cas.lookups.color_dict[cas.lookups.lookup_ori[m][0] + '1'],
    'ori_other_0': cas.lookups.color_dict[cas.lookups.lookup_ori[m][0] + '3'],
    'ori_same_135': cas.lookups.color_dict[cas.lookups.lookup_ori[m][135] + '1'],
    'ori_other_135': cas.lookups.color_dict[cas.lookups.lookup_ori[m][135] + '3'],
    'ori_same_270': cas.lookups.color_dict[cas.lookups.lookup_ori[m][270] + '1'],
    'ori_other_270': cas.lookups.color_dict[cas.lookups.lookup_ori[m][270] + '3'],
    'prev_0': '#ffc562',
    'prev_135': '#ff62d3',
    'prev_270': '#62ffbb',
    'prev_answer': '#ffc905',
    'prev_choice': '#68437d',
    'prev_punish': '#c98b6c',
    'prev_reward': '#ffaf25',
    'cum_reward': '#17cc56',
}
    
    z = flow.Mouse(mouse=m).psytracker(pars=th_pars, force=False, verbose=True)
    
    fig = af.makeWeightPlot(z.fits, z.data, z.weights_dict, perf_plot=True, bias_plot=False, errorbar=z.d['results']['credible_intervals'],
                  label_names=label_names, label_order=label_order, colors=colors)
    
    root = cas.paths.save_dir_groupmouse(
        mice,
        'pillow th nopav new mice',
        method='ncp_hals',
        nan_thresh=0.85,
        score_threshold=0.95,
        pars=None,
        words=['bookmarks'],
        rank_num=' pillow',
        grouping='group',
        group_pars={'group_by': 'all3'})
#     path = os.path.join(root, m + '_psy_pillow_plots_nopav.eps')
    path2 = os.path.join(root, m + '_psy_pillow_plots_pars_th_nopav.pdf')
    if not os.path.isdir(root):
        os.mkdir(root)
#     fig.savefig(path, bbox_inches='tight')
    fig.savefig(path2, bbox_inches='tight')
# Out:
# No PsyTracker found, re-calculating (pars_word=southampton, runs_word=santa).
# * Beginning training for OA27 *
#  Fitting weights:
# {'bias': 1,
#  'ori_0_0': 1,
#  'ori_0_135': 1,
#  'ori_0_270': 1,
#  'ori_135_0': 1,
#  'ori_135_135': 1,
#  'ori_135_270': 1,
#  'ori_270_0': 1,
#  'ori_270_135': 1,
#  'ori_270_270': 1,
#  'prev_choice': 1,
#  'prev_punish': 1,
#  'prev_reward': 1}
#  Fitting 13 total hyper-parameters
# - Collecting data
#  Data keys:
#   ['answer', 'correct', 'dateRunTrials', 'dateRuns', 'dayLength', 'days', 'inputs', 'name', 'runLength', 'y']
#  Inputs:
#   ['ori_0_0', 'ori_0_135', 'ori_0_270', 'ori_135_0', 'ori_135_135', 'ori_135_270', 'ori_270_0', 'ori_270_135', 'ori_270_270', 'prev_choice', 'prev_punish', 'prev_reward']
#  Total trials:
#   11229
# - Fitting model

# %%
 cas.lookups.color_dict
# Out:
# {'plus': [0.46, 0.85, 0.47, 1],
#  'minus': [0.84, 0.12, 0.13, 1],
#  'neutral': [0.28, 0.68, 0.93, 1],
#  'learning': [0.13333333333333333,
#   0.43137254901960786,
#   0.21176470588235294,
#   1],
#  'reversal': [0.6784313725490196, 0.14901960784313725, 0.10196078431372549, 1],
#  'gray': [0.6392156862745098, 0.6392156862745098, 0.6392156862745098, 1],
#  'plus1': '#81ff62',
#  'plus2': '#63ffce',
#  'plus3': '#cdff60',
#  'minus1': '#ff5e79',
#  'minus2': '#ffa561',
#  'minus3': '#ff7b60',
#  'neutral1': '#74c3ff',
#  'neutral2': '#db77ff',
#  'neutral3': '#9476ff'}
